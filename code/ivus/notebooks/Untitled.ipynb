# %%
# !pip install python-dotenv
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/57/c8/5b14d5cffe7bb06bedf9d66c4562bf90330d3d35e7f0266928c370d9dd6d/python_dotenv-0.10.3-py2.py3-none-any.whl
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

RESULTS_FOLDER = os.getenv('RESULTS_FOLDER')

# %%
os.listdir('C:\\Users\\Javier\\Documents\\IVUS-Sequence-Detection\\results\\hp_sh\\summary.csv')
# Out:
# ['summary.csv', 'top_5_best.txt']

# %%
sh_df = pd.read_csv('C:\\Users\\Javier\\Documents\\IVUS-Sequence-Detection\\results\\hp_sh\\summary.csv')

# %%
sh_df.groupby(['model_id']).mean().sort_values(by=[' val_f1'], ascending=False)
# Out:
#               fold    beta_1        lr   recurrent_dropout   lstm_units  \
# model_id
# 76        5.666667  0.978358  0.001115                 0.1         30.0
# 72        5.666667  0.979527  0.001383                 0.1         20.0
# 66        5.666667  0.957752  0.001787                 0.1         22.0
# 19        5.666667  0.767423  0.000378                 0.0         38.0
# 68        5.666667  0.967240  0.001326                 0.1         22.0
# 83        5.666667  0.998736  0.007878                 0.1         26.0
# 99        5.666667  0.839392  0.002286                 0.1         32.0
# 96        5.666667  0.948006  0.000704                 0.3         24.0
# 18        5.666667  0.991892  0.001766                 0.2         58.0
# 62        5.666667  0.952551  0.001721                 0.1         22.0
# 93        5.666667  0.974141  0.002953                 0.1         20.0
# 26        5.666667  0.996811  0.003182                 0.0         44.0
# ...

# %%
sh_df.head()
# Out:
#    model_id   fold    beta_1        lr   recurrent_dropout   lstm_units  \
# 0         1      3  0.822614  0.000354                 0.3         40.0
# 1         1      5  0.822614  0.000354                 0.3         40.0
# 2         1      9  0.822614  0.000354                 0.3         40.0
# 3         2      3  0.927835  0.000253                 0.2         46.0
# 4         2      5  0.927835  0.000253                 0.2         46.0
#
#     epoch      loss       acc        f1   val_loss   val_acc    val_f1  \
# 0     196  0.336205  0.854591  0.527682   0.540207  0.754975  0.455466
# 1      68  0.413249  0.823415  0.442520   0.510567  0.782132  0.540388
# 2     161  0.260444  0.894825  0.559869   0.491654  0.819030  0.632271
# 3      97  0.360819  0.836749  0.514138   0.533247  0.778607  0.446329
# 4     163  0.366144  0.838620  0.468776   0.511390  0.807210  0.602611
#
#           time
# 0  1369.846603
# 1  1587.397929
# 2  1241.712496
# 3  1233.183004
# 4  1356.923630
